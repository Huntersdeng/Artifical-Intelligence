# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
   'food': ['Item0', 'Item0', 'Item1', 'Item1'],
   'ranking': ['Gold', 'Bronze', 'Gold', 'Bronze'],
   'ID': [1, 2, 5, 2],
   'prob': [0.1,0.2,0.3,0.4]
})
df
# Out:
#     food ranking  ID  prob
# 0  Item0    Gold   1   0.1
# 1  Item0  Bronze   2   0.2
# 2  Item1    Gold   5   0.3
# 3  Item1  Bronze   2   0.4

# %%
df.at[:,'newInfo'] = 1
df.at[:,'newInfo2'] = [1,2,3,4]
print(df)
df = df.drop(columns=['newInfo'])
df = df.drop(columns=['newInfo2'])
print(df)
# Out:
#     food ranking  ID  prob  newInfo  newInfo2
# 0  Item0    Gold   1   0.1        1         1
# 1  Item0  Bronze   2   0.2        1         2
# 2  Item1    Gold   5   0.3        1         3
# 3  Item1  Bronze   2   0.4        1         4
#     food ranking  ID  prob
# 0  Item0    Gold   1   0.1
# 1  Item0  Bronze   2   0.2
# 2  Item1    Gold   5   0.3
# 3  Item1  Bronze   2   0.4

# %% [markdown]
# # Any groupby operation involves one of the following operations on the original object. They are −
#
# Splitting the Object
#
# Applying a function
#
# Combining the results
#
# # In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# Aggregation − computing a summary statistic
#
# Transformation − perform some group-specific operation
#
# Filtration − discarding the data with some condition

# %%
print("total column", df.columns)
columns = list(set(df.columns) - {'food'})
print("after deletion",columns)
df_marginalized = df[columns]
print(df_marginalized)
# Out:
# total column Index(['ID', 'food', 'prob', 'ranking'], dtype='object')
# after deletion ['ID', 'prob', 'ranking']
#    ID  prob ranking
# 0   1   0.1    Gold
# 1   2   0.2  Bronze
# 2   5   0.3    Gold
# 3   2   0.4  Bronze

# %%
#as_index : boolean, default True
#For aggregated output, return object with group labels as the index. 
#Only relevant for DataFrame input. as_index=False is effectively “SQL-style” grouped output
#check other default values at https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html

# %%
res = df[columns].groupby(['ID','ranking'], as_index=False).sum()
print(res)
# Out:
#    ID ranking  prob
# 0   1    Gold   0.1
# 1   2  Bronze   0.6
# 2   5    Gold   0.3

# %%
a = [1, 2, 3, 4, 5]
b = ['a', 'b', 'c', 'd', 'e']

zipped = zip(a, b) # Output: Zip Object. <zip at 0x108a81108>
list(zipped) # [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]

# %%
df_ID_2 = df[df['ID'] == 2]
print(df_ID_2)
# Out:
#    ID   food  prob ranking
# 1   2  Item0   0.2  Bronze
# 3   2  Item1   0.4  Bronze

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
df_a = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
raw_data = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
df_b = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_b
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}
df_n = pd.DataFrame(raw_data, columns = ['subject_id','test_id'])
df_n
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
#Join the two dataframes along rows
df_new = pd.concat([df_a, df_b])
df_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
#Join the two dataframes along columns
pd.concat([df_a, df_b], axis=1)
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
#Join the two dataframes along columns
pd.concat([df_a, df_n], axis=1)
# Out:
#   subject_id first_name last_name subject_id  test_id
# 0          1       Alex  Anderson          1       51
# 1          2        Amy  Ackerman          2       15
# 2          3      Allen       Ali          3       15
# 3          4      Alice      Aoni          4       61
# 4          5     Ayoung   Atiches          5       16
# 5        NaN        NaN       NaN          7       14
# 6        NaN        NaN       NaN          8       15
# 7        NaN        NaN       NaN          9        1
# 8        NaN        NaN       NaN         10       61
# 9        NaN        NaN       NaN         11       16

# %%
pd.merge(df_new, df_n, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
from IPython.display import Image
Image(filename='join.png')
# to join two factors, there are two cases
# case1: no overlapping column names, hence you can just use merge
#

# %%
pd.merge(df_new, df)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-36-3606a96c196b> in <module>()
# ----> 1 pd.merge(df_new, df)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     558             warnings.warn(msg, UserWarning)
#     559
# ...
